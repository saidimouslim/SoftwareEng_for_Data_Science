# %% [markdown]
# <figure>
#   <IMG src="figures/logo-esi-sba.png" WIDTH=300 height="100" ALIGN="right">
# </figure>
#
# # Practical Trainining Series on Software Engineering For Data Science
# *By Dr. Belkacem KHALDI (b.khaldi@esi-sba.dz)*

# %% [markdown]
# # Notebook 8: Data Processing & Cleaning for Data Science: Statistics For Data Science
#
# The purpose of this [Jupyter Notebook] is to getting you familairized with Statistics For Data Science

# %% [markdown]
# #  Bayes' law
# Use Bayes’ law to calculate the probability of getting a data science job if you’ve gotten an interview for the job. This could be written P(get the DS job | interview). You’ll have to use Bayesian probability methods (your intuition or beliefs) to assign values to the different components of Bayes’ law.
#
# `Hint:`
# * Usually the probability of getting a job from applying is very low, around 1%. This is based on experience and reading about how most people apply to 100 jobs in order to get 1 job.
# * P(interview | get job) is 99%. Almost no one will hire someone they didn't interview.
# * P(interview | !get job) will be set to 10%. We might interview 10% of candidates, and only one gets the job.

# %%
#Your Solution
p_job = 0.01 
p_not_job = 1 - p_job
p_int_job = 0.99
p_int_notjob = 0.1
p_job_int = (p_int_job * p_job) / (p_int_job * p_job + p_int_notjob * p_not_job)
print(f'P(get the DS job | interview) = {p_job_int}')
# Out:
# P(get the DS job | interview) = 0.09090909090909091

# %% [markdown]
# #  Probabilities Distributions
#
# Re-test the codes seen in lecture 8 from slide 6 to 18.

# %%
#Your Solution
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
x = np.linspace(-4, 4, 100)
plt.plot(x, norm.pdf(x))
plt.plot(x, norm.cdf(x))

# %%
data = norm.rvs(size=10000, random_state=42)
plt.hist(data, bins=30)
# Out:
# (array([3.000e+00, 1.000e+00, 6.000e+00, 1.300e+01, 2.800e+01, 4.700e+01,
#         8.100e+01, 1.710e+02, 2.330e+02, 3.970e+02, 5.040e+02, 7.040e+02,
#         8.330e+02, 9.540e+02, 1.044e+03, 1.027e+03, 9.880e+02, 8.290e+02,
#         6.500e+02, 5.260e+02, 3.670e+02, 2.590e+02, 1.580e+02, 8.100e+01,
#         4.900e+01, 2.400e+01, 1.500e+01, 5.000e+00, 1.000e+00, 2.000e+00]),
#  array([-3.92240025e+00, -3.66077899e+00, -3.39915772e+00, -3.13753646e+00,
#         -2.87591519e+00, -2.61429393e+00, -2.35267266e+00, -2.09105139e+00,
#         -1.82943013e+00, -1.56780886e+00, -1.30618760e+00, -1.04456633e+00,
#         -7.82945068e-01, -5.21323803e-01, -2.59702538e-01,  1.91872741e-03,
#          2.63539993e-01,  5.25161258e-01,  7.86782523e-01,  1.04840379e+00,
#          1.31002505e+00,  1.57164632e+00,  1.83326758e+00,  2.09488885e+00,
#          2.35651011e+00,  2.61813138e+00,  2.87975265e+00,  3.14137391e+00,
#          3.40299518e+00,  3.66461644e+00,  3.92623771e+00]),
#  <BarContainer object of 30 artists>)

# %%
x = np.linspace(12, 16, 100)
plt.plot(x, norm.pdf(x, loc=14, scale=0.5))

# %%
data = norm.rvs(size=10000, loc=14, scale=0.5,
    random_state=42)

# %%
print(data.mean())
print(data.std())
# Out:
# 13.998932008315789
# 0.5017061030649937

# %%
import pandas as pd

# %%
df = pd.read_csv('data/solar_cell_efficiencies.csv')
df.describe()
# Out:
#           efficiency
# count  187196.000000
# mean       14.181805
# std         0.488751
# min         9.691218
# 25%        13.932445
# 50%        14.205567
# 75%        14.482341
# max        17.578530

# %%
import scipy

# %%
scipy.stats.norm.fit(df['efficiency'])
# Out:
# (14.181805365742568, 0.4887500401256815)

# %%
scipy.stats.bernoulli(p=0.7).rvs()
# Out:
# 0

# %%
binom_dist = scipy.stats.binom(p=0.7, n=10)
plt.bar(range(11), binom_dist.pmf(k=range(11)))
# Out:
# <BarContainer object of 11 artists>

# %%
r = scipy.stats.uniform.rvs(size=1000)
sns.distplot(r)
# Out:
# /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# !pip install matplotlib-label-lines==0.3.0
# Out:
# Collecting matplotlib-label-lines==0.3.0
#   Using cached matplotlib_label_lines-0.3.0-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: numpy in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib-label-lines==0.3.0) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib-label-lines==0.3.0) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->matplotlib-label-lines==0.3.0) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/abdelkrimzitouni/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-label-lines==0.3.0) (1.16.0)
# Installing collected packages: matplotlib-label-lines
# Successfully installed matplotlib-label-lines-0.3.0

# %%
from labellines import labelLines
x = np.linspace(0, 5, 100)
plt.plot(x, scipy.stats.expon.pdf(x, scale=1), label='λ=1')
plt.plot(x, scipy.stats.expon.pdf(x, scale=0.25), label='λ=4')
labelLines(plt.gca().get_lines())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qh/q0gs86q124x9czkvbyj6hkf00000gn/T/ipykernel_3145/3920924748.py in <module>
#       3 plt.plot(x, scipy.stats.expon.pdf(x, scale=1), label='λ=1')
#       4 plt.plot(x, scipy.stats.expon.pdf(x, scale=0.25), label='λ=4')
# ----> 5 labelLines(plt.gca().get_lines())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/labellines/core.py in labelLines(lines, align, xvals, **kwargs)
#      76
#      77     '''
# ---> 78     ax = lines[0].get_axes()
#      79     labLines = []
#      80     labels = []
#
# AttributeError: 'Line2D' object has no attribute 'get_axes'

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, scipy.stats.weibull_min(c=3).pdf(x))

# %%
x = range(1, 50)
plt.plot(x, scipy.stats.zipf(a=1.1).pmf(x), marker='.')

# %%
df = pd.read_csv('data/solar_cell_efficiencies.csv')
df.sample(100, random_state=42)
# Out:
#         efficiency
# 87591    13.405397
# 158602   14.404034
# 107515   14.458128
# 116535   14.260624
# 184959   14.336878
# ...            ...
# 158398   14.292562
# 32960    14.725099
# 29208    14.186570
# 175322   14.054062
# 6312     13.388618
#
# [100 rows x 1 columns]

# %%
df = pd.read_csv('data/solar_cell_efficiencies.csv')
df.sample(100, random_state=42)
# Out:
#         efficiency
# 87591    13.405397
# 158602   14.404034
# 107515   14.458128
# 116535   14.260624
# 184959   14.336878
# ...            ...
# 158398   14.292562
# 32960    14.725099
# 29208    14.186570
# 175322   14.054062
# 6312     13.388618
#
# [100 rows x 1 columns]

# %%
import seaborn as sns

# %%
means = []
for i in range(10000):
    sample = np.random.choice(df['efficiency'], 1000,
    replace=True)
    means.append(sample.mean())

sns.histplot(means)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # MISO distributions
# Determine the type of distribution and extract the distribution's PDF parameters from the MISO wind power generation data (the MWh column), stored under  data/miso_wind_data.csv. Write a short analysis explaining why you chose that distribution and what the parameters mean.
#
# `Hint:`
# Try to fit your data with different probabilities distributions and see what one works better.

# %%
miso = pd.read_csv('data/miso_wind_data.csv')
miso.describe()
# Out:
#        Hour Ending
# count  8784.000000
# mean     12.500000
# std       6.922581
# min       1.000000
# 25%       6.750000
# 50%      12.500000
# 75%      18.250000
# max      24.000000

# %%
miso.head()
# Out:
#   Market Day  Hour Ending       MWh
# 0   1/1/2020            1  12161.42
# 1   1/1/2020            2  13090.65
# 2   1/1/2020            3  13597.16
# 3   1/1/2020            4  13638.77
# 4   1/1/2020            5  13320.79

# %% [markdown]
# *Converting `MWh` to numeric*

# %%
miso = miso.astype({'MWh': 'float64'})

# %%
miso.describe()
# Out:
#        Hour Ending           MWh
# count  8784.000000   8784.000000
# mean     12.500000   8143.348373
# std       6.922581   4352.807392
# min       1.000000    -33.580000
# 25%       6.750000   4432.852500
# 50%      12.500000   7756.870000
# 75%      18.250000  11726.047500
# max      24.000000  19966.710000

# %%
sns.histplot(miso['MWh'], kde=True, color='b')
# Out:
# <AxesSubplot:xlabel='MWh', ylabel='Count'>

# %% [markdown]
# # Bootstrap Sampling
# Apply bootstrap sampling to the MISO wind power generation data and plot the distribution of the mean wind power generation values.

# %%
#your solution
